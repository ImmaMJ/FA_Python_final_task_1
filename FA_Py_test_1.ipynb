# %% [markdown]
# <a href="https://colab.research.google.com/github/ImmaMJ/FA_Python_final_task_1/blob/main/FA_Py_test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Загрузка данных
df = pd.read_csv('movies_stats.csv')

# Создание списка годов с 1950 по 2010
years = list(range(1950, 2011))

# Функция для определения года выпуска из названия
def production_year(title):
    for year in years:
        if str(year) in title:
            return year
    return 1900

# Добавление нового столбца с годом выпуска
df['year'] = df['title'].apply(production_year)

# Расчет среднего рейтинга по годам и сортировка
average_ratings = df.groupby('year')['rating'].mean().sort_values(ascending=False)

print(average_ratings)
# Out:
# year
# 1957    4.014241
# 1972    4.011136
# 1952    4.000000
# 1954    3.994220
# 1951    3.983539
#           ...
# 2005    3.448434
# 2003    3.444777
# 1996    3.426600
# 1997    3.415764
# 2000    3.356104
# Name: rating, Length: 62, dtype: float64
